# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
from pathlib import Path
from shapely import MultiPoint, normalize, Point, voronoi_polygons,intersection
import geopandas as gpd
import folium
from itertools import pairwise
from pyroutelib3 import Router, distHaversine
import pyroutelib3.router as rt
from tqdm import tqdm
from random import shuffle
import json
# %matplotlib qt

from geovoronoi.plotting import subplot_for_map,plot_voronoi_polys, plot_voronoi_polys_with_points_in_area
from geovoronoi import voronoi_regions_from_coords, points_to_coords

# %%
base_url = 'https://en.wikipedia.org'
station_file_path = Path('./stations.json')
def get_coords(link):
  r = requests.get(base_url + link)
  soup = BeautifulSoup(r.text, 'html.parser')
  coordstring = soup.find(class_="geo").text.strip()
  tuplestring = tuple(map(float, coordstring.split(';')))
  return (tuplestring[1], tuplestring[0])
if station_file_path.exists():
  stations = pd.read_json(station_file_path)
else:
  url = "https://en.wikipedia.org/wiki/List_of_Montreal_Metro_stations"
  stations = pd.read_html(url)[1]
  response = requests.get(url)
  soup = BeautifulSoup(response.text, 'html.parser')
  table = soup.find_all('table')[1]
  links = []
  for tr in table.findAll("tr"):
    trs = tr.findAll("th")
    for each in trs:
      try:
        link = each.find('a')['href']
        links.append(link)
      except:
        pass
  stations['Link']=links[1:]
  stations['coords'] = stations['Link'].apply(get_coords)
  stations.to_json(station_file_path)

# %%
stations['coords']
# Out:
# 0     [-73.60361, 45.44611]
# 1     [-73.59306, 45.45139]
# 2     [-73.58194, 45.45667]
# 3     [-73.57167, 45.45944]
# 4     [-73.56694, 45.46278]
#               ...
# 63      [-73.6237, 45.5305]
# 64       [-73.62, 45.53528]
# 65    [-73.60722, 45.54778]
# 66    [-73.60194, 45.55361]
# 67        [-73.6, 45.55972]
# Name: coords, Length: 68, dtype: object

# %%
# router = Router('car', 
#                 'montreal.osm.pbf',
#                 localfileType='pbf')
#router = Router('foot')
router = Router('foot','montreal_canada.osm.pbf',localfileType='pbf')
for coord in stations['coords']:
    router.getArea(coord[1],coord[0])
stations['node'] = list(map(lambda x: router.findNode(x[1],x[0]),stations['coords']))

# %%
stations['node_coord'] = list(map(router.nodeLatLon,stations['node']))

# %%
status, route = router.doRoute(8997083710,6188320842)
list(map(router.nodeLatLon, route))
# Out:
# [(45.524976, -73.5820202), (45.5249321, -73.5820603)]

# %%
router.report()
# Out:
# Loaded 1805162 nodes
# Loaded 3983780 foot edges

# %%
canada = gpd.read_file('./lpr_000b16a_e.shp')
canada = canada.to_crs('WGS84')

# %%
quebec = canada[canada['PRENAME'] == 'Quebec']
quebecgeo = quebec.iloc[0]['geometry']
montrealgeo = list(quebecgeo.geoms)[3]

# %%
montrealgeo.contains(Point(-73.5820202,45.524976))
# Out:
# True

# %%
fig, ax = plt.subplots(figsize=(12,12))
quebec.plot(ax=ax)
ax.set_xlim(-73.75,-73.472)
ax.set_ylim(45.398,45.623)

for i in range(len(stations)):
  d = stations.iloc[i]
  cds = d['coords']
  ncds = d['node_coord']
  ax.plot(cds[0], cds[1],  marker='o', markersize=8,color='C1', zorder=10)
  ax.plot(ncds[1], ncds[0],  marker='o', markersize=8,color='C2', zorder=10)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,12))
quebec.plot(ax=ax)
ax.set_xlim(-73.75,-73.472)
ax.set_ylim(45.398,45.623)

lats = []
longs = [] 
for n,loc in router.rnodes.items():
  lats.append(loc[0])
  longs.append(loc[1])
  
ax.scatter(longs, lats,  marker='o', s=8,color='C2', zorder=10)

plt.show()

# %%
def total_distance(node1,node2,router):
    status, route = router.doRoute(node1,node2)
    return sum([distHaversine(router.nodeLatLon(p[0]),router.nodeLatLon(p[1])) for p in pairwise(route)]), route
    
def find_station(node,stations,router):
    # Heuristic, find three closest straight line stations
    # and only check these ones.
    dists = {}
    for name,s_node in stations.items():
        dist = distHaversine(router.nodeLatLon(node),router.nodeLatLon(s_node))
        dists[name] = dist
    closest_two = sorted(dists.items(),key=lambda x: x[1])[:2]
    closest_two = list(map(lambda x:x[0],closest_two))
    if dists[closest_two[0]] < dist[closest_two[1]]/2:
        return closest_two[0], router.doRoute(node,stations[closest_two][1])
    dists = {}
    routes = {}
    for name in closest_two:
        d, r = total_distance(node,stations[name],router)
        dists[name] = d
        routes[name] = r
    name = sorted(dists.items(),key=lambda x: x[1])[0][0]
    return name, routes[name]

# %%
s_n_dict = dict(zip(stations['Name'].to_list(),stations['node'].to_list()))

# %%
nodes_file_path = Path("./done_nodes.json")
if nodes_file_path.exists():
    with nodes_file_path.open('r') as f:
        node_stations = json.load(f)
#node_stations = {n : None for n in tqdm(router.rnodes.keys()) if montrealgeo.contains(Point(router.nodeLatLon(n)[1],router.nodeLatLon(n)[0]))}
# Out:
# 100%|██████████| 1805162/1805162 [12:18<00:00, 2444.68it/s]

# %%
fig, ax = plt.subplots(figsize=(12,12))
quebec.plot(ax=ax)
ax.set_xlim(-73.75,-73.472)
ax.set_ylim(45.398,45.623)

lats = []
longs = [] 
for n in node_stations:
  loc = router.nodeLatLon(n)
  lats.append(loc[0])
  longs.append(loc[1])
  
ax.scatter(longs, lats,  marker='o', s=8,color='C2', zorder=10)

plt.show()

# %%
for n in node_stations.keys():
    node_stations[n] = None

# %%
rt.SEARCH_LIMIT = 5000
ns = [n for n,station in node_stations.items() if station is None]
shuffle(ns)
completed = 0
for n in tqdm(ns):
    if node_stations[n] is None:
        # If all neighbouring nodes share the same closest station
        # ngbrs = router.routing[n].keys()
        # ngbrs_stations = [node_stations[ngbr] for ngbr in ngbrs]
        # ngbrs_set = set(ngbrs_stations)

        # if len(set(ngbrs_stations)) == 1 and ngbrs_set != set([None]):
        #     node_stations[n] = ngbrs_stations.pop()
        # else:
            try:
                station, route = find_station(n,s_n_dict,router)
                if route == []:
                    continue
                for n in route:
                    node_stations[n] = station
            except RuntimeError:
                continue
            completed += 1
# Out:
#   4%|▍         | 11124/271062 [20:28<7:58:29,  9.05it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[126], line 16
#       6 if node_stations[n] is None:
#       7     # If all neighbouring nodes share the same closest station
#       8     # ngbrs = router.routing[n].keys()
#    (...)
#      13     #     node_stations[n] = ngbrs_stations.pop()
#      14     # else:
#      15         try:
# ---> 16             station, route = find_station(n,s_n_dict,router)
#      17             if route == []:
#      18                 continue
#
# Cell In[41], line 17, in find_station(node, stations, router)
#      15 routes = {}
#      16 for name in closest_two:
# ---> 17     d, r = total_distance(node,stations[name],router)
#      18     dists[name] = d
#      19     routes[name] = r
#
# Cell In[41], line 2, in total_distance(node1, node2, router)
#       1 def total_distance(node1,node2,router):
# ----> 2     status, route = router.doRoute(node1,node2)
#       3     return sum([distHaversine(router.nodeLatLon(p[0]),router.nodeLatLon(p[1])) for p in pairwise(route)]), route
#
# File c:\Users\Rigel\miniconda3\envs\voronoi\Lib\site-packages\pyroutelib3\router.py:150, in Router.doRoute(self, start, end)
#     147     continue
#     149 # Gather info about added item
# --> 150 distance = self.distance(toNodePos, endLocation)
#     151 newItem = _AStarQueueItem(
#     152     node=toNode,
#     153     routeTo=currItem.routeTo + [toNode],
#    (...)
#     156     forceNext=currItem.forceNext[1:],
#     157 )
#     159 # Check if a cheaper route to toNode exists
#
# File c:\Users\Rigel\miniconda3\envs\voronoi\Lib\site-packages\pyroutelib3\util.py:51, in distHaversine(n1, n2)
#      46 dlathalf = (lat2 - lat1) * 0.5
#      47 dlonhalf = (lon2 - lon1) * 0.5
#      49 sqrth = math.sqrt(
#      50     (math.sin(dlathalf) ** 2)
# ---> 51     + (math.cos(lat1) * math.cos(lat2) * (math.sin(dlonhalf) ** 2))
#      52 )
#      54 return math.asin(sqrth) * 2 * 6371
#
# KeyboardInterrupt:

# %%
queues = {name:set([]) for name in s_n_dict.keys()}
to_check = {name:node for name,node in s_n_dict.items()}
unvisited = set(node_stations.keys())
while len(unvisited) != 0:
    print(unvisited)
    for name in s_n_dict.keys():
        for node in to_check:
            if node_stations[node] is not None:
                pass
# Out:
# {8997083710: None,
#  6188320842: 'Mont-Royal',
#  8996944085: 'Mont-Royal',
#  8996944097: 'Mont-Royal',
#  5022472271: 'Mont-Royal',
#  8996944106: None,
#  26232575: None,
#  7450479409: None,
#  26232576: None,
#  7450479417: None,
#  26232577: None,
#  510601161: None,
#  7450479410: None,
#  7450479411: None,
#  26232581: 'Guy–Concordia formerly Guy',
#  4618656365: None,
#  6828696715: None,
#  6828696716: None,
#  6828696717: None,
#  6828696718: None,
#  26232619: None,
#  6828696719: None,
#  26232618: None,
#  6828696720: None,
#  26232617: None,
#  8329284921: None,
#  213649537: 'Mont-Royal',
#  6767549861: 'Mont-Royal',
#  1330277118: 'Mont-Royal',
#  26232896: 'Viau',
#  26232893: 'Viau',
#  1454537655: 'Mont-Royal',
#  8997083697: 'Mont-Royal',
#  8997083696: 'Mont-Royal',
#  2148401275: 'Mont-Royal',
#  225104813: 'Mont-Royal',
#  3373392916: 'Mont-Royal',
#  8997083688: 'Mont-Royal',
#  209424717: 'Mont-Royal',
#  26233006: None,
#  6893619161: 'Berri–UQAM formerly Berri-de Montigny',
#  26233012: 'Berri–UQAM formerly Berri-de Montigny',
#  9030151348: 'Berri–UQAM formerly Berri-de Montigny',
#  9030151349: 'Berri–UQAM formerly Berri-de Montigny',
#  9030151350: 'Berri–UQAM formerly Berri-de Montigny',
#  9029466686: 'Berri–UQAM formerly Berri-de Montigny',
#  29239099: None,
#  26235235: 'Place-des-Arts',
#  9738612358: 'Place-des-Arts',
#  1245728019: 'Place-des-Arts',
#  8025526256: 'Place-des-Arts',
#  9627374323: None,
#  1245728010: 'Place-des-Arts',
#  10099144265: 'Place-des-Arts',
#  7181863872: 'Place-des-Arts',
#  3391106830: 'Place-des-Arts',
#  3391106831: 'Place-des-Arts',
#  3391106832: 'Place-des-Arts',
#  1315075428: 'Saint-Laurent',
#  3398341074: 'Saint-Laurent',
#  26233200: 'Saint-Laurent',
#  445787786: 'Atwater',
#  445787787: 'Atwater',
#  29796380: 'Atwater',
#  29796724: None,
#  4011656237: 'Guy–Concordia formerly Guy',
#  1200671689: 'Guy–Concordia formerly Guy',
#  1199366704: 'Guy–Concordia formerly Guy',
#  1200671686: None,
#  1200671808: None,
#  4023852617: 'Guy–Concordia formerly Guy',
#  26233212: 'Guy–Concordia formerly Guy',
#  9217289467: 'Guy–Concordia formerly Guy',
#  4170243625: 'Guy–Concordia formerly Guy',
#  4020398399: 'Guy–Concordia formerly Guy',
#  1192154366: None,
#  1192163638: None,
#  1192154322: None,
#  1192163643: None,
#  3390027967: 'Guy–Concordia formerly Guy',
#  26233211: 'Guy–Concordia formerly Guy',
#  3390027961: 'Guy–Concordia formerly Guy',
#  6244449852: 'Guy–Concordia formerly Guy',
#  1195283008: 'Guy–Concordia formerly Guy',
#  1278641529: "Lucien-L'Allier",
#  1195282851: "Lucien-L'Allier",
#  3445236727: "Lucien-L'Allier",
#  3185399529: "Lucien-L'Allier",
#  29796356: "Lucien-L'Allier",
#  437808230: 'Champ-de-Mars',
#  7066644085: 'Champ-de-Mars',
#  1178670198: 'Champ-de-Mars',
#  26233328: 'Champ-de-Mars',
#  9033505338: 'Champ-de-Mars',
#  9032084027: 'Champ-de-Mars',
#  9032084028: 'Champ-de-Mars',
#  9033484214: None,
#  4001206738: 'Champ-de-Mars',
#  5995731359: None,
#  6718439536: 'Champ-de-Mars',
#  26233324: 'Champ-de-Mars',
#  471723743: None,
#  9476139763: 'Champ-de-Mars',
#  3994645934: 'Champ-de-Mars',
#  5995731381: 'Champ-de-Mars',
#  26233310: 'Champ-de-Mars',
#  7166987557: 'Champ-de-Mars',
#  3998348691: 'Champ-de-Mars',
#  26233308: None,
#  3998348694: 'Champ-de-Mars',
#  9476139760: 'Champ-de-Mars',
#  2007138984: None,
#  26233307: 'Champ-de-Mars',
#  2007138921: 'Champ-de-Mars',
#  9325266895: 'Champ-de-Mars',
#  9325266887: 'Champ-de-Mars',
#  215702333: 'Champ-de-Mars',
#  26233293: 'Champ-de-Mars',
#  9325266862: 'Champ-de-Mars',
#  208962832: 'Champ-de-Mars',
#  9036244597: 'Champ-de-Mars',
#  9036244600: 'Champ-de-Mars',
#  208932307: 'Champ-de-Mars',
#  1246412314: 'Champ-de-Mars',
#  4001204466: None,
#  2007138999: 'Champ-de-Mars',
#  26233313: 'Champ-de-Mars',
#  471723770: "Place-d'Armes",
#  516806298: "Place-d'Armes",
#  1061986856: "Place-d'Armes",
#  2694679524: "Place-d'Armes",
#  26233381: "Place-d'Armes",
#  26233377: "Place-d'Armes",
#  3624815855: "Place-d'Armes",
#  26233378: "Place-d'Armes",
#  26233372: "Place-d'Armes",
#  10273320588: "Place-d'Armes",
#  10273320575: "Place-d'Armes",
#  26233302: None,
#  10273320574: "Place-d'Armes",
#  460315112: "Place-d'Armes",
#  10273320576: "Place-d'Armes",
#  1996285352: "Place-d'Armes",
#  465635388: "Place-d'Armes",
#  1996285336: "Place-d'Armes",
#  1309044553: "Place-d'Armes",
#  26235146: "Place-d'Armes",
#  215722845: "Place-d'Armes",
#  26233299: "Place-d'Armes",
#  3470839946: "Place-d'Armes",
#  215729309: "Place-d'Armes",
#  9654221254: "Place-d'Armes",
#  465634364: "Place-d'Armes",
#  465635494: "Place-d'Armes",
#  10278642674: "Place-d'Armes",
#  5995731366: "Place-d'Armes",
#  2695094426: "Place-d'Armes",
#  26233370: "Place-d'Armes",
#  32124780: "Place-d'Armes",
#  9654221257: "Place-d'Armes",
#  9654221276: "Place-d'Armes",
#  9654221259: "Place-d'Armes",
#  26235133: "Place-d'Armes",
#  29287991: 'De Castelnau',
#  3358280672: 'De Castelnau',
#  3426156429: 'De Castelnau',
#  438343154: 'De Castelnau',
#  289407299: None,
#  2435266544: None,
#  29483027: None,
#  29483029: None,
#  9910759875: None,
#  8935933503: None,
#  1734441030: None,
#  1734441153: None,
#  8935933500: None,
#  9910759876: None,
#  29483031: None,
#  289407491: None,
#  1279463727: None,
#  8935933513: None,
#  29483033: None,
#  1573732124: None,
#  1279463755: None,
#  29483034: None,
#  6513267690: None,
#  3096149019: None,
#  3096149015: None,
#  213673804: None,
#  303447164: None,
#  6784248799: None,
#  2434430213: None,
#  29483036: None,
#  3383436800: None,
#  213673801: None,
#  6513267687: None,
#  1573732122: None,
#  300096417: None,
#  2434454015: None,
#  209377819: None,
#  3964969120: None,
#  2148062859: None,
#  30453320: None,
#  1699799551: None,
#  1704419702: None,
#  1699799712: None,
#  4520704482: None,
#  4109567674: None,
#  8632391175: None,
#  9654936883: 'Côte-Vertu',
#  9654936882: None,
#  29217083: None,
#  9920059908: None,
#  9920132505: None,
#  9920157221: None,
#  9649232558: None,
#  9649232555: None,
#  9424175320: None,
#  9920170450: None,
#  29217089: None,
#  31242498: None,
#  209377834: None,
#  4132790990: None,
#  30453569: None,
#  3964969127: None,
#  2148062863: None,
#  3930097848: None,
#  3930097840: None,
#  6720067013: None,
#  3930087118: None,
#  9709192388: None,
#  3964969125: None,
#  213649583: 'Mont-Royal',
#  8016511665: 'Mont-Royal',
#  29784597: 'Mont-Royal',
#  31705444: 'Mont-Royal',
#  8387919428: None,
#  29793292: None,
#  10209971068: 'Place-des-Arts',
#  6869470001: 'Place-des-Arts',
#  936010425: 'Place-des-Arts',
#  208765244: 'Place-des-Arts',
#  7181949565: 'Place-des-Arts',
#  208765229: 'Place-des-Arts',
#  26232428: 'Mont-Royal',
#  1859173330: 'Mont-Royal',
#  31701547: 'Mont-Royal',
#  29796354: "Place-d'Armes",
#  3398341084: "Place-d'Armes",
#  3391132741: "Place-d'Armes",
#  9910411635: "Place-d'Armes",
#  3391132745: "Place-d'Armes",
#  29796359: "Place-d'Armes",
#  29796375: 'Georges-Vanier',
#  445067522: None,
#  29796624: 'Atwater',
#  445067521: 'Atwater',
#  666064993: 'Atwater',
#  29796938: "Lucien-L'Allier",
#  4027387144: "Lucien-L'Allier",
#  1199664477: None,
#  1195282824: "Lucien-L'Allier",
#  1195282818: None,
#  3390027953: 'Guy–Concordia formerly Guy',
#  26233213: None,
#  4020503213: 'Guy–Concordia formerly Guy',
#  1195283011: 'Guy–Concordia formerly Guy',
#  1195282905: 'Guy–Concordia formerly Guy',
#  391401351: 'Guy–Concordia formerly Guy',
#  9217289470: 'Guy–Concordia formerly Guy',
#  29796937: 'Guy–Concordia formerly Guy',
#  4035216433: 'Guy–Concordia formerly Guy',
#  4024427768: 'Guy–Concordia formerly Guy',
#  581020633: None,
#  29217075: None,
#  2485523858: None,
#  30453322: None,
#  30453406: 'Outremont',
#  9203266269: 'Outremont',
#  8955576591: 'Outremont',
#  209386990: 'Édouard-Montpetit',
#  31278764: 'Édouard-Montpetit',
#  31243426: None,
#  31242310: None,
#  9920706072: None,
#  9920863195: None,
#  9920871795: None,
#  9920863118: None,
#  9920867721: None,
#  31243109: None,
#  9920863154: None,
#  31242628: None,
#  33588904: None,
#  215062696: 'Du Collège',
#  215062655: 'Du Collège',
#  31243751: None,
#  217741323: None,
#  217741376: None,
#  3997748443: None,
#  3997748442: None,
#  217753152: None,
#  9168515148: None,
#  31244117: None,
#  9161157525: None,
#  4357666165: None,
#  6967612222: None,
#  3909227053: None,
#  217741419: None,
#  4343186664: None,
#  3997961165: None,
#  4343186665: None,
#  3997961164: None,
#  3997961163: None,
#  9170695188: None,
#  31244118: None,
#  9168491445: None,
#  29583130: None,
#  3997961162: None,
#  217815609: 'De La Savane',
#  3997961161: 'De La Savane',
#  217815615: 'De La Savane',
#  3997961160: 'De La Savane',
#  3997961159: 'De La Savane',
#  3997961158: 'De La Savane',
#  3997961157: 'De La Savane',
#  217815597: 'De La Savane',
#  217704465: 'Namur',
#  6625119783: 'Namur',
#  282143614: 'Namur',
#  3383436908: 'Namur',
#  4686973304: 'Plamondon',
#  9421636828: None,
#  8177583243: None,
#  3922811638: None,
#  2365967496: None,
#  4182338476: None,
#  4182338487: None,
#  4182338472: None,
#  4190983257: None,
#  4190983255: None,
#  3929568211: None,
#  4190983253: None,
#  4190983259: None,
#  2068559109: None,
#  8179259897: None,
#  4190983262: None,
#  4190983264: None,
#  209370671: None,
#  1988609145: None,
#  716011812: None,
#  9659669459: None,
#  9659669379: None,
#  9659669380: None,
#  3647600917: None,
#  9920813017: None,
#  4739777272: None,
#  9920890311: None,
#  31242524: None,
#  9920863180: None,
#  5246511490: None,
#  9920863181: None,
#  9920863185: None,
#  4739777415: None,
#  9920890333: None,
#  4739777414: None,
#  9920863182: None,
#  9920863183: None,
#  3752756431: None,
#  9920863184: None,
#  9920890337: None,
#  4739777432: None,
#  9920890338: None,
#  31410090: None,
#  9659669428: None,
#  606802227: None,
#  9661694068: None,
#  9661206037: None,
#  1843396778: None,
#  6761487386: None,
#  9659669434: None,
#  9796411873: None,
#  9659669436: None,
#  31393657: None,
#  306011122: None,
#  4114852847: None,
#  2148212966: None,
#  2148212970: None,
#  3964969108: None,
#  306011129: None,
#  618066347: 'Guy–Concordia formerly Guy',
#  1574804136: 'Guy–Concordia formerly Guy',
#  6624759141: 'Guy–Concordia formerly Guy',
#  31362125: 'Guy–Concordia formerly Guy',
#  305543112: None,
#  9953326399: None,
#  1704789481: None,
#  3931267425: None,
#  1704789551: None,
#  3931506428: None,
#  213476584: None,
#  29796843: None,
#  9455671980: None,
#  29796844: None,
#  8551875166: None,
#  2885828525: None,
#  2885724321: None,
#  2885724315: None,
#  8928483119: 'Radisson',
#  8928617424: 'Radisson',
#  246653338: 'Radisson',
#  9023324155: 'Berri–UQAM formerly Berri-de Montigny',
#  9024017453: 'Berri–UQAM formerly Berri-de Montigny',
#  1382525048: 'Berri–UQAM formerly Berri-de Montigny',
#  217993542: 'Berri–UQAM formerly Berri-de Montigny',
#  9025649155: 'Berri–UQAM formerly Berri-de Montigny',
#  1382525072: 'Berri–UQAM formerly Berri-de Montigny',
#  9025649189: 'Berri–UQAM formerly Berri-de Montigny',
#  6893619152: 'Berri–UQAM formerly Berri-de Montigny',
#  9025649192: 'Berri–UQAM formerly Berri-de Montigny',
#  29482320: None,
#  1573732100: None,
#  1282768735: None,
#  301154442: None,
#  31700050: None,
#  7170069408: None,
#  1573732063: None,
#  303434465: None,
#  9905098400: None,
#  3885449394: None,
#  1573723051: None,
#  1573705335: None,
#  31700076: None,
#  1500348619: 'Édouard-Montpetit',
#  1573711060: 'Édouard-Montpetit',
#  1573711073: 'Édouard-Montpetit',
#  31700077: 'Édouard-Montpetit',
#  1573705362: 'Édouard-Montpetit',
#  7170069401: 'Édouard-Montpetit',
#  31700055: None,
#  29794113: 'Laurier',
#  8892311847: 'Laurier',
#  31700339: 'Laurier',
#  8892311845: 'Laurier',
#  31700340: 'Laurier',
#  31700341: 'Laurier',
#  8892311843: 'Laurier',
#  31700342: 'Laurier',
#  8892311841: 'Laurier',
#  31700343: 'Laurier',
#  31700345: 'Laurier',
#  8892311844: 'Laurier',
#  31776971: None,
#  213759796: 'Pie-IX',
#  29239079: 'Laurier',
#  3199024093: 'Laurier',
#  124524582: 'Laurier',
#  31700818: 'Laurier',
#  31700819: 'Laurier',
#  31701023: 'Outremont',
#  8657048129: 'Outremont',
#  8795014840: 'Outremont',
#  1818906503: 'Outremont',
#  3691058821: None,
#  31701022: 'Outremont',
#  29796373: None,
#  4711840739: 'Georges-Vanier',
#  445067529: 'Georges-Vanier',
#  3390027970: None,
#  3390027968: 'Guy–Concordia formerly Guy',
#  213389732: 'Guy–Concordia formerly Guy',
#  4825623305: None,
#  31704892: None,
#  661857258: None,
#  4823800443: None,
#  31704891: None,
#  31704890: None,
#  6481106364: None,
#  31704889: None,
#  31704888: None,
#  6481106363: None,
#  4823800442: None,
#  31704693: None,
#  6481106362: None,
#  31704478: None,
#  932400525: None,
#  31704479: None,
#  932400512: None,
#  31704922: 'Mont-Royal',
#  1038433038: 'Mont-Royal',
#  9307175728: 'Mont-Royal',
#  7795299486: 'Mont-Royal',
#  596988539: None,
#  1038433036: 'Mont-Royal',
#  7795296784: 'Mont-Royal',
#  4504112770: 'Mont-Royal',
#  31705660: 'Mont-Royal',
#  4504112771: None,
#  1038433028: None,
#  29239083: None,
#  8676616640: 'Mont-Royal',
#  3383056827: 'Mont-Royal',
#  7795296768: 'Mont-Royal',
#  6549188469: 'Mont-Royal',
#  6549188468: 'Mont-Royal',
#  5854728420: 'Mont-Royal',
#  29239085: 'Mont-Royal',
#  124062159: None,
#  3194230967: None,
#  1575104804: None,
#  10209971071: None,
#  31706064: 'Place-des-Arts',
#  1573548251: 'Place-des-Arts',
#  1244412452: 'Place-des-Arts',
#  3383231137: 'Place-des-Arts',
#  8676596858: 'Place-des-Arts',
#  31705722: 'Place-des-Arts',
#  31706264: 'McGill',
#  4515421371: 'McGill',
#  31706263: None,
#  31706262: 'McGill',
#  4515421370: 'McGill',
#  31706123: 'McGill',
#  1573548268: 'McGill',
#  4515421369: None,
#  1573548282: None,
#  1573548286: 'Place-des-Arts',
#  1244412453: 'Place-des-Arts',
#  31706062: 'McGill',
#  3383231141: 'McGill',
#  31706407: None,
#  31706404: 'Place-des-Arts',
#  31706403: 'Place-des-Arts',
#  467589548: 'Place-des-Arts',
#  3383231128: 'Place-des-Arts',
#  2626194656: 'Place-des-Arts',
#  31706267: None,
#  29793981: 'McGill',
#  1028394506: 'McGill',
#  1550150652: 'McGill',
#  29793982: 'McGill',
#  10051917493: 'Sherbrooke',
#  31776104: 'Sherbrooke',
#  10051917503: 'Sherbrooke',
#  31776107: 'Sherbrooke',
#  31776108: 'Sherbrooke',
#  31776109: 'Sherbrooke',
#  458918557: 'Sherbrooke',
#  8026251884: 'Sherbrooke',
#  31776110: 'Sherbrooke',
#  31776133: 'Place-des-Arts',
#  31776134: 'Place-des-Arts',
#  31705840: 'Place-des-Arts',
#  10028093369: None,
#  1575102253: 'Place-des-Arts',
#  1566771182: 'Place-des-Arts',
#  678766332: 'Place-des-Arts',
#  31776038: 'Place-des-Arts',
#  1558888310: 'Laurier',
#  1566787146: 'Laurier',
#  1417691410: 'Laurier',
#  3584133910: 'Laurier',
#  8892311851: 'Laurier',
#  878749924: 'Laurier',
#  4170308277: 'Laurier',
#  438328642: 'Laurier',
#  29794080: 'Mont-Royal',
#  6925594154: 'Mont-Royal',
#  6925594155: 'Mont-Royal',
#  31777081: 'Mont-Royal',
#  31777082: 'Mont-Royal',
#  31777083: 'Mont-Royal',
#  31777084: 'Mont-Royal',
#  2148357499: 'Mont-Royal',
#  31777085: 'Mont-Royal',
#  2148352594: 'Mont-Royal',
#  31777086: 'Mont-Royal',
#  1345062960: 'Mont-Royal',
#  9004842337: 'Mont-Royal',
#  31777087: None,
#  29795235: 'Laurier',
#  31777152: 'Laurier',
#  31777153: 'Laurier',
#  3691422728: 'Laurier',
#  29794110: 'Laurier',
#  414448512: 'Laurier',
#  31701631: 'Laurier',
#  31777167: 'Laurier',
#  290287297: None,
#  3199018550: 'Laurier',
#  31776937: 'Laurier',
#  8892311860: 'Laurier',
#  1528884541: 'Laurier',
#  3591067040: 'Laurier',
#  1528884599: 'Laurier',
#  1456706550: None,
#  31700662: 'Laurier',
#  31700824: 'Laurier',
#  1456706552: 'Laurier',
#  1528884601: 'Laurier',
#  1528884603: 'Laurier',
#  1528884577: 'Laurier',
#  31777169: 'Laurier',
#  31777188: 'Laurier',
#  8993064902: None,
#  3389786852: 'Laurier',
#  299836991: 'Laurier',
#  8993137690: 'Laurier',
#  31777175: 'Laurier',
#  30453005: None,
#  1778791554: None,
#  1778791553: None,
#  1573620080: None,
#  31777145: None,
#  8252752080: None,
#  31776848: None,
#  32124773: "Place-d'Armes",
#  215729261: None,
#  32124763: 'Square-Victoria–OACI formerly Square-Victoria',
#  3470654429: None,
#  462248743: 'Square-Victoria–OACI formerly Square-Victoria',
#  6864077044: 'Square-Victoria–OACI formerly Square-Victoria',
#  1207405301: None,
#  32125619: 'McGill',
#  3383231145: None,
#  32125620: 'Place-des-Arts',
#  32125624: 'Place-des-Arts',
#  4515421362: 'Place-des-Arts',
#  32125662: 'Place-des-Arts',
#  32125663: 'Place-des-Arts',
#  1374347287: 'Place-des-Arts',
#  32125664: 'Place-des-Arts',
#  32125665: 'Place-des-Arts',
#  32125666: 'Place-des-Arts',
#  1374347293: 'Place-des-Arts',
#  1374347272: 'Place-des-Arts',
#  1374347190: 'Place-des-Arts',
#  1374347334: 'Place-des-Arts',
#  32125677: 'Place-des-Arts',
#  32582567: 'Côte-Vertu',
#  9656141630: 'Côte-Vertu',
#  215062556: None,
#  213573535: 'Plamondon',
#  9438031527: 'Plamondon',
#  4587061852: 'Plamondon',
#  611533074: 'Plamondon',
#  2363498190: 'Plamondon',
#  9421636765: 'Plamondon',
#  213573510: 'Plamondon',
#  9421636766: 'Plamondon',
#  9421621390: 'Plamondon',
#  213573506: 'Plamondon',
#  9421621391: 'Plamondon',
#  9421621356: None,
#  213573503: 'Plamondon',
#  9421621357: 'Plamondon',
#  9421479613: 'Plamondon',
#  213573499: 'Plamondon',
#  9421479612: 'Plamondon',
#  9421479569: 'Plamondon',
#  32583673: 'Plamondon',
#  32661735: 'LaSalle',
#  2189086755: 'LaSalle',
#  1700518225: 'LaSalle',
#  2189086748: 'LaSalle',
#  1700518223: 'LaSalle',
#  2189086757: 'LaSalle',
#  1700518222: 'LaSalle',
#  2189086761: None,
#  1700518221: 'LaSalle',
#  1764284042: None,
#  1764284043: None,
#  1764259766: None,
#  1764259774: None,
#  1764259776: None,
#  1669417935: None,
#  1700105830: None,
#  1700105815: None,
#  5235662460: None,
#  5235662461: None,
#  1700105814: None,
#  1700105828: None,
#  32663225: None,
#  1764259733: None,
#  32664664: None,
#  32664657: None,
#  32664658: None,
#  6376146273: None,
#  32664659: None,
#  6376146272: None,
#  32664574: None,
#  1704424022: None,
#  8540810782: None,
#  8540810780: None,
#  5570716593: None,
#  8540762620: None,
#  5015624905: None,
#  1764233556: None,
#  9885489421: None,
#  9817128591: None,
#  1763626781: None,
#  1764233546: None,
#  1764233544: None,
#  1763626780: None,
#  9817128587: None,
#  1763626779: None,
#  9817128629: None,
#  1763626778: None,
#  1387494164: 'Verdun',
#  4844283895: 'Verdun',
#  612002299: None,
#  9821362021: None,
#  9821362022: None,
#  9821362023: None,
#  9821362024: None,
#  32821664: None,
#  9821362025: None,
#  9821362026: None,
#  9821362027: None,
#  9821362028: None,
#  9821362029: None,
#  9821362030: None,
#  32821665: None,
#  9821362031: None,
#  32821666: None,
#  9821362032: None,
#  9821362033: None,
#  1004348287: None,
#  9821362034: None,
#  9885218591: None,
#  32821667: None,
#  9821362035: None,
#  9821362036: None,
#  9821362037: None,
#  32821668: None,
#  9823932315: None,
#  9821362038: None,
#  9821362039: None,
#  9821362040: None,
#  9823932314: None,
#  9821362041: None,
#  9821362042: None,
#  9821362043: None,
#  9885218607: None,
#  32821671: None,
#  9821362044: None,
#  9821362045: None,
#  9821362047: None,
#  9821362046: None,
#  9823932313: None,
#  286449131: None,
#  246283354: None,
#  9523114601: None,
#  3713144670: None,
#  3705936601: None,
#  33575769: None,
#  246283628: None,
#  9461842894: None,
#  9461842890: None,
#  9461842892: None,
#  9461842889: None,
#  9461842893: None,
#  9461842888: None,
#  246283624: None,
#  9461842884: 'Du Collège',
#  215062733: 'Du Collège',
#  48570675: None,
#  9842910343: None,
#  9842886404: None,
#  2267326232: None,
#  9842886401: None,
#  9841646302: None,
#  9841646301: None,
#  48570677: None,
#  32766432: 'Jolicoeur',
#  9882991796: 'Jolicoeur',
#  9882992022: 'Jolicoeur',
#  58852602: None,
#  9981294375: None,
#  286450980: None,
#  1764336825: None,
#  9981294379: None,
#  286451040: None,
#  209424849: 'Mont-Royal',
#  8997083700: 'Mont-Royal',
#  8997083685: None,
#  8997083655: None,
#  8997083694: 'Mont-Royal',
#  8998521368: 'Mont-Royal',
#  8998521376: 'Mont-Royal',
#  209424845: 'Mont-Royal',
#  29796734: "Lucien-L'Allier",
#  3185399526: "Lucien-L'Allier",
#  3445236726: "Lucien-L'Allier",
#  1204313232: "Lucien-L'Allier",
#  29796735: "Lucien-L'Allier",
#  29598757: None,
#  477364682: None,
#  29599057: None,
#  9920863143: None,
#  4739777443: None,
#  4739796953: None,
#  9920863157: None,
#  9920863158: None,
#  9920863159: None,
#  9920863156: None,
#  9920863155: None,
#  29599056: None,
#  9920863153: None,
#  29217092: None,
#  31243405: None,
#  9920769888: None,
#  6860645200: None,
#  9920816508: None,
#  9920816511: None,
#  9920816510: None,
#  9920816509: None,
#  31243404: None,
#  9920816512: None,
#  6175365938: None,
#  9920816513: None,
#  31243403: None,
#  9920816515: None,
#  9920816514: None,
#  9920826859: None,
#  31242531: None,
#  209370661: None,
#  10072958798: 'Plamondon',
#  4587061856: None,
#  2363498191: None,
#  10072958804: None,
#  9421636787: None,
#  59892770: None,
#  9920863136: None,
#  59892756: None,
#  9920863135: None,
#  9920863134: None,
#  31242627: None,
#  96071501: None,
#  8728041250: None,
#  8728041263: None,
#  3640108610: None,
#  8599501384: None,
#  6700018929: None,
#  8599698128: None,
#  16874268: None,
#  6700018940: None,
#  6700018911: None,
#  16874269: None,
#  8599703088: None,
#  2859158918: 'Assomption',
#  30914720: 'Assomption',
#  32124732: 'Place-Saint-Henri',
#  8893408801: 'Place-Saint-Henri',
#  3558668930: 'Place-Saint-Henri',
#  9348839952: 'Place-Saint-Henri',
#  9348839950: 'Place-Saint-Henri',
#  85000155: 'Place-Saint-Henri',
#  9348839951: 'Place-Saint-Henri',
#  9348839953: 'Place-Saint-Henri',
#  84996999: 'Place-Saint-Henri',
#  9348839954: 'Place-Saint-Henri',
#  3557673302: 'Place-Saint-Henri',
#  9348839956: None,
#  9311501340: 'Place-Saint-Henri',
#  84996998: 'Place-Saint-Henri',
#  4542243544: 'Place-Saint-Henri',
#  9348839958: None,
#  9311501345: 'Place-Saint-Henri',
#  3557695496: 'Place-Saint-Henri',
#  9348839961: 'Place-Saint-Henri',
#  333457719: 'Place-Saint-Henri',
#  9348839964: 'Place-Saint-Henri',
#  9348909292: 'Place-Saint-Henri',
#  85001547: 'Place-Saint-Henri',
#  3558668932: 'Place-Saint-Henri',
#  9311501344: 'Place-Saint-Henri',
#  8893408803: 'Place-Saint-Henri',
#  32124731: 'Place-Saint-Henri',
#  4542243546: 'Place-Saint-Henri',
#  9311501341: 'Place-Saint-Henri',
#  9348839957: 'Place-Saint-Henri',
#  3557673304: 'Place-Saint-Henri',
#  89408396: 'Place-Saint-Henri',
#  8023586026: 'Place-Saint-Henri',
#  9348909303: None,
#  3559450514: 'Place-Saint-Henri',
#  8023586035: 'Place-Saint-Henri',
#  32124668: 'Place-Saint-Henri',
#  90443555: None,
#  8821933032: 'Place-Saint-Henri',
#  9348909294: 'Place-Saint-Henri',
#  9348909295: 'Place-Saint-Henri',
#  8821933034: 'Place-Saint-Henri',
#  89408389: 'Place-Saint-Henri',
#  8821933029: 'Place-Saint-Henri',
#  9348909298: None,
#  412638717: 'Place-Saint-Henri',
#  412638580: 'Place-Saint-Henri',
#  3559128787: 'Place-Saint-Henri',
#  9348839940: 'Place-Saint-Henri',
#  90443559: 'Place-Saint-Henri',
#  89408360: 'Lionel-Groulx',
#  9348839941: 'Lionel-Groulx',
#  9348803688: 'Lionel-Groulx',
#  89408354: 'Lionel-Groulx',
#  32124671: 'Place-Saint-Henri',
#  9348839947: None,
#  9348839948: 'Place-Saint-Henri',
#  9348839949: 'Place-Saint-Henri',
#  3557621256: 'Place-Saint-Henri',
#  9348839925: 'Place-Saint-Henri',
#  32124733: 'Place-Saint-Henri',
#  32124736: 'Lionel-Groulx',
#  9181091934: None,
#  7430760528: 'Lionel-Groulx',
#  7430760532: 'Lionel-Groulx',
#  9348803682: 'Lionel-Groulx',
#  32124673: 'Lionel-Groulx',
#  4335915413: 'Lionel-Groulx',
#  9181065864: 'Lionel-Groulx',
#  9683678877: None,
#  412639937: 'Lionel-Groulx',
#  9181220476: 'Lionel-Groulx',
#  412640439: 'Lionel-Groulx',
#  7430760533: 'Lionel-Groulx',
#  9181065863: 'Lionel-Groulx',
#  9181091935: None,
#  32124737: 'Lionel-Groulx',
#  5098156688: 'Lionel-Groulx',
#  9311501333: 'Lionel-Groulx',
#  9311484641: 'Lionel-Groulx',
#  9311484643: 'Lionel-Groulx',
#  9311484642: 'Lionel-Groulx',
#  9322276292: 'Lionel-Groulx',
#  9275329810: 'Lionel-Groulx',
#  32124735: 'Lionel-Groulx',
#  90443622: None,
#  9181065848: 'Lionel-Groulx',
#  412641200: None,
#  3775435739: None,
#  9207308143: None,
#  7405829840: 'Lionel-Groulx',
#  90443619: None,
#  32124739: 'Lionel-Groulx',
#  9181091940: 'Lionel-Groulx',
#  7405829839: 'Lionel-Groulx',
#  9901718625: 'Lionel-Groulx',
#  3555233616: 'Lionel-Groulx',
#  3555234286: 'Lionel-Groulx',
#  412641202: 'Lionel-Groulx',
#  32124678: 'Lionel-Groulx',
#  90443623: 'Lionel-Groulx',
#  9322276273: 'Lionel-Groulx',
#  90443625: 'Lionel-Groulx',
#  32124729: 'Place-Saint-Henri',
#  9275334684: 'Place-Saint-Henri',
#  9348932232: 'Place-Saint-Henri',
#  405129236: 'Place-Saint-Henri',
#  9348932231: None,
#  6710810176: 'Place-Saint-Henri',
#  90443729: 'Place-Saint-Henri',
#  90443735: None,
#  8026755728: 'Place-Saint-Henri',
#  90443743: 'Place-Saint-Henri',
#  90443747: None,
#  9316293801: 'Place-Saint-Henri',
#  90443752: 'Place-Saint-Henri',
#  9348803700: 'Place-Saint-Henri',
#  90443719: 'Place-Saint-Henri',
#  31703080: 'Lionel-Groulx',
#  9311440092: None,
#  9311439478: 'Lionel-Groulx',
#  90443754: 'Lionel-Groulx',
#  9311439479: 'Lionel-Groulx',
#  9322276288: 'Lionel-Groulx',
#  5413887826: 'Lionel-Groulx',
#  90769622: 'Lionel-Groulx',
#  9172353815: 'Lionel-Groulx',
#  9172384217: 'Lionel-Groulx',
#  90443764: 'Lionel-Groulx',
#  9183439048: 'Lionel-Groulx',
#  8023726609: 'Place-Saint-Henri',
#  90443645: None,
#  8023726611: 'Place-Saint-Henri',
#  1237967111: 'Place-Saint-Henri',
#  90443757: 'Lionel-Groulx',
#  90443636: 'Lionel-Groulx',
#  8023726617: 'Lionel-Groulx',
#  2172009130: None,
#  9319449701: 'Lionel-Groulx',
#  9319449705: 'Lionel-Groulx',
#  90443772: 'Lionel-Groulx',
#  9322276290: 'Lionel-Groulx',
#  9311501334: 'Lionel-Groulx',
#  90443776: 'Lionel-Groulx',
#  90443807: 'Lionel-Groulx',
#  1038439034: 'Lionel-Groulx',
#  3775435715: 'Lionel-Groulx',
#  3775435716: 'Lionel-Groulx',
#  3775435717: 'Lionel-Groulx',
#  ...}

# %%
done_nodes = {key:item for key,item in node_stations.items() if item is not None}

# %%
fig, ax = plt.subplots(figsize=(12,12))
quebec.plot(ax=ax,color='gray')
ax.set_xlim(-73.75,-73.472)
ax.set_ylim(45.398,45.623)
from cycler import cycler
dc = cycler(color=['#E8ECFB', '#D9CCE3', '#D1BBD7', '#CAACCB', '#BA8DB4', '#AE76A3', 
                   '#AA6F9E', '#994F88', '#882E72', '#1965B0', '#437DBF', '#5289C7', 
                   '#6195CF', '#7BAFDE', '#4EB265', '#90C987', '#CAE0AB', '#F7F056', 
                   '#F7CB45', '#F6C141', '#F4A736', '#F1932D', '#EE8026', '#E8601C', 
                   '#E65518', '#DC050C', '#A5170E', '#72190E', '#42150A'])
names = set(done_nodes.values())
ax.set_prop_cycle(dc)
for i,name in enumerate(names):
    lats = []
    longs = [] 
    for n in done_nodes.keys():
        if done_nodes[n] == name:
            loc = router.nodeLatLon(n)
            lats.append(loc[0])
            longs.append(loc[1])
        
    ax.scatter(longs, lats,  marker='o', s=8, zorder=10,label=name)

plt.legend()
plt.show()

# %%
import json
with open('./done_nodes.json','w') as f:
    json.dump(node_stations,f)

# %%
router.nodeLatLon(289407299)
# Out:
# (45.5044873, -73.6156014)

# %%
if not quebecgeo.is_valid or quebecgeo.is_empty:
 print('Invalid Geometry')
else:
 print('Geometry Valid')
 
for i, row in stations.iterrows():
  cds = row['coords']
  name = row['Name']
  p = Point(cds[0], cds[1])
  if not quebecgeo.contains(p):
     print(f'{name} ||| OUTSIDE BOUNDARY')
# Out:
# Geometry Valid

# %%
arcords = np.array(list(map(list, stations['coords'].tolist())))
# arcords = np.roll(arcords,1,axis=1)
region_polys, region_pts = voronoi_regions_from_coords(arcords,quebecgeo)
fig, ax = plt.subplots(figsize=(12,12))
plot_voronoi_polys(ax, region_polys)
ax.set_xlim(-73.75,-73.472)
ax.set_ylim(45.398,45.623)
# Out:
# c:\Users\Rigel\miniconda3\envs\voronoi\Lib\site-packages\shapely\set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# c:\Users\Rigel\miniconda3\envs\voronoi\Lib\site-packages\shapely\set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# c:\Users\Rigel\miniconda3\envs\voronoi\Lib\site-packages\shapely\set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# c:\Users\Rigel\miniconda3\envs\voronoi\Lib\site-packages\shapely\set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# c:\Users\Rigel\miniconda3\envs\voronoi\Lib\site-packages\shapely\set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# c:\Users\Rigel\miniconda3\envs\voronoi\Lib\site-packages\shapely\set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# c:\Users\Rigel\miniconda3\envs\voronoi\Lib\site-packages\shapely\set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# c:\Users\Rigel\miniconda3\envs\voronoi\Lib\site-packages\shapely\set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# c:\Users\Rigel\miniconda3\envs\voronoi\Lib\site-packages\shapely\set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# c:\Users\Rigel\miniconda3\envs\voronoi\Lib\site-packages\shapely\set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# c:\Users\Rigel\miniconda3\envs\voronoi\Lib\site-packages\shapely\set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# c:\Users\Rigel\miniconda3\envs\voronoi\Lib\site-packages\shapely\set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[94], line 5
#       3 region_polys, region_pts = voronoi_regions_from_coords(arcords,quebecgeo)
#       4 fig, ax = plt.subplots(figsize=(12,12))
# ----> 5 plot_voronoi_polys(ax, region_polys)
#       6 ax.set_xlim(-73.75,-73.472)
#       7 ax.set_ylim(45.398,45.623)
#
# File c:\Users\Rigel\miniconda3\envs\voronoi\Lib\site-packages\geovoronoi\plotting.py:132, in plot_voronoi_polys(ax, region_polys, color, edgecolor, labels, label_fontsize, label_color, **kwargs)
#     111 def plot_voronoi_polys(ax, region_polys, color=None, edgecolor=None, labels=None, label_fontsize=10, label_color=None,
#     112                        **kwargs):
#     113     """
#     114     Plot Voronoi region polygons in `poly_shapes` on matplotlib Axes object `ax`. Use fill color `color`, edge color
#     115     `edgecolor`. Optionally supply a list of labels `labels` that will be displayed on the respective Voronoi region
#    (...)
#     129     :return: None
#     130     """
# --> 132     plot_polygon_collection_with_color(ax, region_polys, color=color, edgecolor=edgecolor, **kwargs)
#     134     if labels:
#     135         # plot labels using matplotlib's text()
#     136         n_labels = len(labels)
#
# File c:\Users\Rigel\miniconda3\envs\voronoi\Lib\site-packages\geovoronoi\plotting.py:354, in plot_polygon_collection_with_color(ax, geoms, color, **kwargs)
#     351 if 'markersize' in kwargs:
#     352     del kwargs['markersize']
# --> 354 collection = PatchCollection([PolygonPatch(poly) for poly in geoms],
#     355                              color=color_values, **kwargs)
#     357 ax.add_collection(collection, autolim=True)
#     358 ax.autoscale_view()
#
# File c:\Users\Rigel\miniconda3\envs\voronoi\Lib\site-packages\geovoronoi\plotting.py:354, in <listcomp>(.0)
#     351 if 'markersize' in kwargs:
#     352     del kwargs['markersize']
# --> 354 collection = PatchCollection([PolygonPatch(poly) for poly in geoms],
#     355                              color=color_values, **kwargs)
#     357 ax.add_collection(collection, autolim=True)
#     358 ax.autoscale_view()
#
# File c:\Users\Rigel\miniconda3\envs\voronoi\Lib\site-packages\descartes\patch.py:87, in PolygonPatch(polygon, **kwargs)
#      73 def PolygonPatch(polygon, **kwargs):
#      74     """Constructs a matplotlib patch from a geometric object
#      75
#      76     The `polygon` may be a Shapely or GeoJSON-like object with or without holes.
#    (...)
#      85
#      86     """
# ---> 87     return PathPatch(PolygonPath(polygon), **kwargs)
#
# File c:\Users\Rigel\miniconda3\envs\voronoi\Lib\site-packages\descartes\patch.py:62, in PolygonPath(polygon)
#      58     else:
#      59         raise ValueError(
#      60             "A polygon or multi-polygon representation is required")
# ---> 62 vertices = concatenate([
#      63     concatenate([asarray(t.exterior)[:, :2]] +
#      64                 [asarray(r)[:, :2] for r in t.interiors])
#      65     for t in polygon])
#      66 codes = concatenate([
#      67     concatenate([coding(t.exterior)] +
#      68                 [coding(r) for r in t.interiors]) for t in polygon])
#      70 return Path(vertices, codes)
#
# File c:\Users\Rigel\miniconda3\envs\voronoi\Lib\site-packages\descartes\patch.py:63, in <listcomp>(.0)
#      58     else:
#      59         raise ValueError(
#      60             "A polygon or multi-polygon representation is required")
#      62 vertices = concatenate([
# ---> 63     concatenate([asarray(t.exterior)[:, :2]] +
#      64                 [asarray(r)[:, :2] for r in t.interiors])
#      65     for t in polygon])
#      66 codes = concatenate([
#      67     concatenate([coding(t.exterior)] +
#      68                 [coding(r) for r in t.interiors]) for t in polygon])
#      70 return Path(vertices, codes)
#
# IndexError: too many indices for array: array is 0-dimensional, but 2 were indexed

# %%
region_polys
# Out:
# {0: <MULTIPOLYGON (((-73.591 45.43, -73.592 45.43, -73.592 45.43, -73.592 45.43,...>,
#  1: <POLYGON ((-73.704 45.544, -73.704 45.545, -73.704 45.545, -73.703 45.545, -...>,
#  2: <MULTIPOLYGON (((-73.593 45.465, -73.58 45.468, -73.579 45.468, -73.58 45.46...>,
#  3: <MULTIPOLYGON (((-73.604 45.46, -73.593 45.465, -73.593 45.465, -73.586 45.4...>,
#  4: <MULTIPOLYGON (((-73.578 45.469, -73.574 45.467, -73.564 45.454, -73.564 45....>,
#  5: <POLYGON ((-73.574 45.467, -73.56 45.466, -73.56 45.466, -73.56 45.465, -73....>,
#  6: <POLYGON ((-73.714 45.437, -73.714 45.437, -73.715 45.437, -73.715 45.438, -...>,
#  7: <POLYGON ((-73.722 45.438, -73.723 45.438, -73.723 45.438, -73.724 45.439, -...>,
#  8: <POLYGON ((-73.635 45.596, -73.653 45.525, -73.654 45.525, -73.667 45.531, -...>,
#  9: <POLYGON ((-73.575 45.574, -73.585 45.605, -73.533 45.573, -73.575 45.574))>,
#  10: <POLYGON ((-73.545 45.54, -73.563 45.55, -73.539 45.551, -73.528 45.548, -73...>,
#  11: <POLYGON ((-73.539 45.551, -73.563 45.566, -73.574 45.569, -73.576 45.553, -...>,
#  12: <POLYGON ((-73.545 45.54, -73.567 45.533, -73.569 45.535, -73.574 45.543, -7...>,
#  13: <POLYGON ((-73.563 45.529, -73.567 45.533, -73.545 45.54, -73.536 45.54, -73...>,
#  14: <POLYGON ((-73.595 45.543, -73.586 45.545, -73.579 45.55, -73.617 45.562, -7...>,
#  15: <POLYGON ((-73.586 45.545, -73.597 45.515, -73.593 45.509, -73.574 45.543, -...>,
#  16: <POLYGON ((-73.61 45.491, -73.607 45.49, -73.618 45.46, -73.653 45.443, -73....>,
#  17: <MULTIPOLYGON (((-73.618 45.46, -73.607 45.49, -73.604 45.492, -73.597 45.48...>,
#  18: <POLYGON ((-73.602 45.497, -73.623 45.513, -73.632 45.51, -73.61 45.491, -73...>,
#  19: <POLYGON ((-73.562 45.528, -73.563 45.529, -73.542 45.528, -73.543 45.527, -...>,
#  20: <POLYGON ((-73.602 45.518, -73.597 45.515, -73.593 45.509, -73.593 45.509, -...>,
#  21: <POLYGON ((-73.602 45.518, -73.597 45.515, -73.586 45.545, -73.595 45.543, -...>,
#  22: <POLYGON ((-73.612 45.529, -73.608 45.541, -73.597 45.544, -73.595 45.543, -...>,
#  23: <POLYGON ((-73.626 45.572, -73.635 45.596, -73.653 45.525, -73.649 45.523, -...>,
#  24: <POLYGON ((-73.622 45.565, -73.617 45.562, -73.597 45.544, -73.608 45.541, -...>,
#  25: <POLYGON ((-73.589 45.614, -73.592 45.62, -73.508 45.578, -73.509 45.576, -7...>,
#  26: <POLYGON ((-73.585 45.605, -73.575 45.574, -73.574 45.569, -73.576 45.553, -...>,
#  27: <POLYGON ((-73.603 45.64, -73.603 45.64, -73.603 45.64, -73.602 45.641, -73....>,
#  28: <MULTIPOLYGON (((-73.516 45.568, -73.516 45.568, -73.516 45.568, -73.516 45....>,
#  29: <POLYGON ((-73.539 45.551, -73.563 45.566, -73.52 45.564, -73.521 45.562, -7...>,
#  30: <POLYGON ((-73.516 45.568, -73.515 45.568, -73.517 45.567, -73.518 45.566, -...>,
#  31: <MULTIPOLYGON (((-73.573 45.483, -73.576 45.478, -73.576 45.478, -73.576 45....>,
#  32: <MULTIPOLYGON (((-73.597 45.484, -73.586 45.483, -73.579 45.475, -73.58 45.4...>,
#  33: <POLYGON ((-73.582 45.488, -73.581 45.49, -73.595 45.506, -73.602 45.497, -7...>,
#  34: <POLYGON ((-73.568 45.487, -73.576 45.493, -73.576 45.496, -73.571 45.499, -...>,
#  35: <POLYGON ((-73.576 45.493, -73.581 45.49, -73.582 45.488, -73.573 45.483, -7...>,
#  36: <POLYGON ((-73.576 45.493, -73.581 45.49, -73.595 45.506, -73.593 45.509, -7...>,
#  37: <POLYGON ((-73.582 45.511, -73.59 45.509, -73.576 45.496, -73.571 45.499, -7...>,
#  38: <POLYGON ((-73.579 45.513, -73.579 45.513, -73.569 45.535, -73.574 45.543, -...>,
#  39: <MULTIPOLYGON (((-73.571 45.499, -73.571 45.5, -73.567 45.502, -73.557 45.49...>,
#  40: <MULTIPOLYGON (((-73.577 45.471, -73.576 45.472, -73.575 45.473, -73.575 45....>,
#  41: <POLYGON ((-73.567 45.504, -73.579 45.513, -73.582 45.511, -73.571 45.5, -73...>,
#  42: <POLYGON ((-73.544 45.484, -73.538 45.483, -73.539 45.478, -73.54 45.477, -7...>,
#  43: <MULTIPOLYGON (((-73.564 45.506, -73.561 45.51, -73.553 45.503, -73.553 45.5...>,
#  44: <POLYGON ((-73.567 45.502, -73.567 45.504, -73.564 45.506, -73.564 45.506, -...>,
#  45: <POLYGON ((-73.57 45.513, -73.579 45.513, -73.579 45.513, -73.567 45.504, -7...>,
#  46: <POLYGON ((-73.612 45.529, -73.621 45.543, -73.627 45.537, -73.616 45.528, -...>,
#  47: <POLYGON ((-73.621 45.543, -73.619 45.55, -73.622 45.565, -73.626 45.572, -7...>,
#  48: <POLYGON ((-73.616 45.528, -73.617 45.527, -73.644 45.526, -73.637 45.533, -...>,
#  49: <POLYGON ((-73.612 45.529, -73.612 45.529, -73.608 45.541, -73.619 45.55, -7...>,
#  50: <POLYGON ((-73.612 45.529, -73.612 45.529, -73.606 45.525, -73.602 45.518, -...>,
#  51: <POLYGON ((-73.642 45.48, -73.632 45.504, -73.633 45.51, -73.647 45.518, -73...>,
#  52: <POLYGON ((-73.632 45.504, -73.627 45.492, -73.62 45.488, -73.61 45.491, -73...>,
#  53: <POLYGON ((-73.647 45.518, -73.649 45.523, -73.644 45.526, -73.617 45.527, -...>,
#  54: <POLYGON ((-73.642 45.48, -73.627 45.492, -73.632 45.504, -73.642 45.48))>,
#  55: <POLYGON ((-73.654 45.525, -73.653 45.525, -73.649 45.523, -73.647 45.518, -...>,
#  56: <MULTIPOLYGON (((-73.659 45.439, -73.666 45.432, -73.666 45.432, -73.667 45....>,
#  57: <POLYGON ((-73.642 45.48, -73.627 45.492, -73.62 45.488, -73.653 45.443, -73...>,
#  58: <POLYGON ((-73.56 45.511, -73.566 45.515, -73.562 45.523, -73.557 45.514, -7...>,
#  59: <POLYGON ((-73.557 45.514, -73.562 45.523, -73.562 45.528, -73.546 45.515, -...>,
#  60: <POLYGON ((-73.566 45.515, -73.57 45.513, -73.579 45.513, -73.569 45.535, -7...>,
#  61: <POLYGON ((-73.56 45.511, -73.561 45.51, -73.564 45.506, -73.564 45.506, -73...>,
#  62: <MULTIPOLYGON (((-73.561 45.51, -73.56 45.511, -73.557 45.514, -73.547 45.51...>,
#  63: <POLYGON ((-73.736 45.67, -73.736 45.67, -73.736 45.671, -73.736 45.671, -73...>,
#  64: <POLYGON ((-73.692 45.682, -73.691 45.682, -73.691 45.683, -73.691 45.683, -...>,
#  65: <POLYGON ((-73.713 45.541, -73.713 45.541, -73.713 45.541, -73.714 45.541, -...>}

# %%
fig,ax = plt.subplots(figsize=(12,12),dpi=300)
station_points = MultiPoint(arcords)
polys = voronoi_polygons(station_points,extend_to=quebecgeo)
region_polys, region_pts = voronoi_regions_from_coords(arcords,quebecgeo)
for p in polys.geoms:
    gpd.GeoSeries(intersection(p,quebecgeo)).plot(ax=ax)
plt.xlim(-73.75,-73.472)
plt.ylim(45.398,45.623)
plt.scatter(arcords[:,0],arcords[:,1],zorder=100,
            marker='o', s=8,color='C1')
plt.show()
# Out:
# c:\Users\Rigel\miniconda3\envs\voronoi\Lib\site-packages\shapely\set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# c:\Users\Rigel\miniconda3\envs\voronoi\Lib\site-packages\shapely\set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# c:\Users\Rigel\miniconda3\envs\voronoi\Lib\site-packages\shapely\set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# c:\Users\Rigel\miniconda3\envs\voronoi\Lib\site-packages\shapely\set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# c:\Users\Rigel\miniconda3\envs\voronoi\Lib\site-packages\shapely\set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# c:\Users\Rigel\miniconda3\envs\voronoi\Lib\site-packages\shapely\set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# c:\Users\Rigel\miniconda3\envs\voronoi\Lib\site-packages\shapely\set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# c:\Users\Rigel\miniconda3\envs\voronoi\Lib\site-packages\shapely\set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# c:\Users\Rigel\miniconda3\envs\voronoi\Lib\site-packages\shapely\set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# c:\Users\Rigel\miniconda3\envs\voronoi\Lib\site-packages\shapely\set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# c:\Users\Rigel\miniconda3\envs\voronoi\Lib\site-packages\shapely\set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# c:\Users\Rigel\miniconda3\envs\voronoi\Lib\site-packages\shapely\set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)

# %%
m = folium.Map(location=[45.50884, -73.58781], zoom_start=13, tiles='CartoDB positron')
for count, r in enumerate(region_polys.values()):
  dfindex = region_pts[count][0]
  d = stations.loc[dfindex]
  name = d['Name']

  popup = f'{name} Station'

  geo_j = folium.GeoJson(data=r, style_function=lambda x: {'color' : 'silver'}, tooltip = name)
  folium.Popup(popup).add_to(geo_j)
  geo_j.add_to(m)

for i in range(len(stations)):
  d = stations.iloc[i]
  cds = d['coords']
  name = d['Name']
  #col = d['COL']

  folium.Circle(
    radius=50,
    location=[cds[1], cds[0]],
    popup = name,
    #color = f'#{col}',
    fill=True,
    tooltip = name).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8e26156f9713cefcd0d149ddc0d87f81 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8e26156f9713cefcd0d149ddc0d87f81&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8e26156f9713cefcd0d149ddc0d87f81 = L.map(
#                 &quot;map_8e26156f9713cefcd0d149ddc0d87f81&quot;,
#                 {
#                     center: [45.50884, -73.58781],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9b70077d11d4f4de68ad3af3939e7175 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8e26156f9713cefcd0d149ddc0d87f81);
#
#
#         function geo_json_f46fad960a09db5dda964b5fd0c78cf3_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;silver&quot;};
#             }
#         }
#
#         function geo_json_f46fad960a09db5dda964b5fd0c78cf3_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_f46fad960a09db5dda964b5fd0c78cf3 = L.geoJson(null, {
#                 onEachFeature: geo_json_f46fad960a09db5dda964b5fd0c78cf3_onEachFeature,
#
#                 style: geo_json_f46fad960a09db5dda964b5fd0c78cf3_styler,
#         });
#
#         function geo_json_f46fad960a09db5dda964b5fd0c78cf3_add (data) {
#             geo_json_f46fad960a09db5dda964b5fd0c78cf3
#                 .addData(data)
#                 .addTo(map_8e26156f9713cefcd0d149ddc0d87f81);
#         }
#             geo_json_f46fad960a09db5dda964b5fd0c78cf3_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-73.5910658346486, 45.43035725661321], [-73.59154587188878, 45.43007514362034], [-73.59192476855125, 45.42974677460545], [-73.59201916036933, 45.429549903458884], [-73.59205434162652, 45.429163276798924], [-73.59200702782252, 45.42900968303406], [-73.59179133011793, 45.428944002012905], [-73.59159985105238, 45.42893264877539], [-73.59096357126099, 45.42881678748199], [-73.59046938308774, 45.428639669413904], [-73.59024340419187, 45.42847484927235], [-73.58995911943165, 45.42808428952581], [-73.58980821922498, 45.427983403324184], [-73.5895398420549, 45.42798009417769], [-73.58915309361944, 45.42811034407188], [-73.5889831552097, 45.42826126335916], [-73.58844931855215, 45.42865072969012], [-73.58831812301999, 45.4287352173979], [-73.58827628756892, 45.428651625729565], [-73.58905355182516, 45.428001082433475], [-73.58954970686503, 45.42758415959924], [-73.58955777701856, 45.42726021586759], [-73.58993129302964, 45.42714780531438], [-73.59017769639014, 45.42700683137068], [-73.59081863926251, 45.42642066207124], [-73.5909392662846, 45.42619709917181], [-73.59127800315102, 45.42594024814551], [-73.59154862195341, 45.42585357458962], [-73.59219541787486, 45.42554650872911], [-73.59264686159293, 45.4252843306128], [-73.59290874299806, 45.42513223963005], [-73.59328962955958, 45.42472288038594], [-73.5946925415157, 45.423821999349926], [-73.59527828574123, 45.42339715429158], [-73.59564523642192, 45.4230326263828], [-73.59594427198657, 45.422829260316945], [-73.59598325369687, 45.42280273412864], [-73.59606014634696, 45.42279468062732], [-73.59604425547526, 45.42292049285613], [-73.59575487139733, 45.42324999609096], [-73.59527178996844, 45.42365810615598], [-73.59416595333452, 45.42443660858225], [-73.59390413050049, 45.4246854412313], [-73.59317710339748, 45.42513553877952], [-73.59287672290867, 45.425392875322224], [-73.59272346272779, 45.42550080127599], [-73.59251240981042, 45.42564942344216], [-73.59212432766147, 45.425833679475176], [-73.59194007596462, 45.42604743592603], [-73.59190801512968, 45.42630806517764], [-73.59197886155378, 45.42654298221199], [-73.5921414132843, 45.42668900362348], [-73.59239387020523, 45.426818143115774], [-73.5926315454226, 45.42702807906435], [-73.59292324629011, 45.42712168950894], [-73.59307435921605, 45.42721358470151], [-73.59322365983064, 45.42737743849029], [-73.5938817219235, 45.42764658133855], [-73.59403441747968, 45.42767547019288], [-73.59421488344019, 45.427614673956256], [-73.5942431149984, 45.4275070011642], [-73.59432234959279, 45.42745056644939], [-73.59451641230369, 45.427312344854265], [-73.59466078263024, 45.42716109103011], [-73.5953070592569, 45.42635892671077], [-73.59698873597975, 45.42452533357255], [-73.59711919062428, 45.42441891630308], [-73.5974711330753, 45.424144209924485], [-73.59781206824465, 45.423797335690786], [-73.59843637250091, 45.42336394505304], [-73.59970215443539, 45.42231731525155], [-73.60
